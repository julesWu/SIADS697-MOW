# %% [markdown]
# # Hawaii Airbnb and POI data

# %% [markdown]
# Essentially, this notebook would be used to scrape through the Hawaii data and incorporate heatmaps. Utilizing both airbnb and POI data, we can see the attractions nearby certain airbnb neighborhoods.

# %%
# Libraries to download
import pandas as pd
import sys
import scipy
import numpy as np
try:
    import folium
except:
    # !{sys.executable} -m pip install folium
    import folium
from folium import plugins
from folium.plugins import MarkerCluster
try:
    import altair as alt
except:
    # !{sys.executable} -m pip install altair
    import altair as alt

# %% [markdown]
# Getting the Hawaii dataset. This is mostly the "detailed" listings csv from InsideAirbnb data, and gives more details/more listing ids for us to use.

# %%
airbnb_data = pd.read_csv('./hawaii_listings.csv')
airbnb_data['count'] = 1
airbnb_data
# Out:
#              id                            listing_url     scrape_id  \
# 0          5065      https://www.airbnb.com/rooms/5065  2.020000e+13
# 1          5269      https://www.airbnb.com/rooms/5269  2.020000e+13
# 2          5387      https://www.airbnb.com/rooms/5387  2.020000e+13
# 3          5389      https://www.airbnb.com/rooms/5389  2.020000e+13
# 4          5390      https://www.airbnb.com/rooms/5390  2.020000e+13
# ...         ...                                    ...           ...
# 21803  50898372  https://www.airbnb.com/rooms/50898372  2.020000e+13
# 21804  50898551  https://www.airbnb.com/rooms/50898551  2.020000e+13
# 21805  50900058  https://www.airbnb.com/rooms/50900058  2.020000e+13
# 21806  50900602  https://www.airbnb.com/rooms/50900602  2.020000e+13
# 21807  50901374  https://www.airbnb.com/rooms/50901374  2.020000e+13
#
#       last_scraped                                               name  \
# 0         7/9/2021                                           MAUKA BB
# 1         7/9/2021          Upcountry Hospitality in the 'Auwai Suite
# 2         7/9/2021                Hale Koa Studio & 1 Bedroom Units!!
# 3         7/9/2021                                      Keauhou Villa
# 4         7/9/2021                              STAY AT PRINCE KUHIO!
# ...            ...                                                ...
# 21803     7/9/2021  1 Bedroom Ocean Front Condo in Honokowai - Sle...
# 21804     7/9/2021  1 Bedroom Ocean Front Condo in Honokowai - Sle...
# 21805     7/9/2021  Hawaii Life Rentals Presents Island Sands 110 ...
# 21806     7/9/2021  Maui Resort Rentals: Honua Kai – Incredible 6 ...
# 21807     7/9/2021  Luxury Home in Lanikai, Ocean Views, Pool, A/C...
#
#                                              description  \
# 0      Perfect for your vacation, Staycation or just ...
# 1      The 'Auwai Suite is a lovely, self-contained a...
# 2      This Wonderful Spacious Studio apt/flat is in ...
# 3      It is less than 10 minute walk to the Keauhou ...
# 4      <b>The space</b><br />Prince Kuhio, Studio Uni...
# ...                                                  ...
# 21803  Ocean Front Ecstasy! Homey w/Tile Floor, Full ...
# 21804  This 1-bedroom oceanfront suite includes all t...
# 21805  This beautiful, ground-floor honeymoon condo i...
# 21806  This stunning offering combines a stunning 3br...
# 21807  Welcome to Paradise! Enjoy Amazing Ocean Views...
#
#                                    neighborhood_overview  \
# 0      Neighbors here are friendly but are not really...
# 1      We are located on the "sunny side" of Waimea, ...
# 2      IN a Farm belt area with small commercial farm...
# 3      It is less than 10 minute walk to the Keauhou ...
# 4                                                    NaN
# ...                                                  ...
# 21803                                                NaN
# 21804                                                NaN
# 21805                                                NaN
# 21806  With a prime beachfront location on West Maui'...
# 21807                                                NaN
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/36718112/1f0e...       7257
# 1      https://a0.muscache.com/pictures/5b52b72f-5a09...       7620
# 2      https://a0.muscache.com/pictures/1170713/dca6a...       7878
# 3      https://a0.muscache.com/pictures/15520396/3b89...       7878
# 4      https://a0.muscache.com/pictures/12955/af97ac5...       7887
# ...                                                  ...        ...
# 21803  https://a0.muscache.com/pictures/prohost-api/H...  118578746
# 21804  https://a0.muscache.com/pictures/prohost-api/H...  118578746
# 21805  https://a0.muscache.com/pictures/prohost-api/H...     680107
# 21806  https://a0.muscache.com/pictures/prohost-api/H...   39073224
# 21807  https://a0.muscache.com/pictures/prohost-api/H...  107293305
#
#                                           host_url  ... review_scores_value  \
# 0           https://www.airbnb.com/users/show/7257  ...                4.76
# 1           https://www.airbnb.com/users/show/7620  ...                4.82
# 2           https://www.airbnb.com/users/show/7878  ...                4.74
# 3           https://www.airbnb.com/users/show/7878  ...                4.74
# 4           https://www.airbnb.com/users/show/7887  ...                4.67
# ...                                            ...  ...                 ...
# 21803  https://www.airbnb.com/users/show/118578746  ...                 NaN
# 21804  https://www.airbnb.com/users/show/118578746  ...                 NaN
# 21805     https://www.airbnb.com/users/show/680107  ...                 NaN
# 21806   https://www.airbnb.com/users/show/39073224  ...                 NaN
# 21807  https://www.airbnb.com/users/show/107293305  ...                 NaN
#
#                                                  license instant_bookable  \
# 0                                                    NaN                f
# 1                                       119-269-5808-01R                f
# 2                                                    NaN                t
# 3                                                    NaN                f
# 4                                               42652226                f
# ...                                                  ...              ...
# 21803                                 GE-140-773-5808-01                t
# 21804                                                NaN                t
# 21805                                                NaN                t
# 21806                                    175-718-1952-01                t
# 21807  430020420000, 326 Lanipo Drive, TA-032-430-336...                f
#
#       calculated_host_listings_count  \
# 0                                  1
# 1                                  3
# 2                                  3
# 3                                  3
# 4                                  1
# ...                              ...
# 21803                            137
# 21804                            137
# 21805                            137
# 21806                            261
# 21807                            210
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               3
# 2                                               3
# 3                                               3
# 4                                               1
# ...                                           ...
# 21803                                         137
# 21804                                         137
# 21805                                         137
# 21806                                         257
# 21807                                         210
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
# ...                                            ...
# 21803                                            0
# 21804                                            0
# 21805                                            0
# 21806                                            4
# 21807                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                               0              0.41
# 1                                               0              0.10
# 2                                               0              1.66
# 3                                               0              0.57
# 4                                               0              2.07
# ...                                           ...               ...
# 21803                                           0               NaN
# 21804                                           0               NaN
# 21805                                           0               NaN
# 21806                                           0               NaN
# 21807                                           0               NaN
#
#       closeness_attractions count
# 0                        30     1
# 1                        36     1
# 2                        24     1
# 3                        23     1
# 4                        92     1
# ...                     ...   ...
# 21803                    60     1
# 21804                    60     1
# 21805                    60     1
# 21806                    60     1
# 21807                   194     1
#
# [21808 rows x 76 columns]

# %% [markdown]
# Getting attraction info from POI factory. Mostly locations that are recommendations for tourists to use.
#
# The dataset is located in http://www.poi-factory.com/node/21535, where we combined the files we found valuable into one master csv.

# %%
usapoi_data = pd.read_csv('./poi_factory/poi_hawaii_data.csv')
usapoi_data
# Out:
#       longitude   latitude                                               name  \
# 0   -159.492460  21.885750                 Allerton National Botanical Garden
# 1   -159.475740  22.212730                             Hanalei Valley Lookout
# 2   -159.562670  21.919870                                   Hanapepe Lookout
# 3   -159.335350  22.042570                                  Hikinaakala Heiau
# 4   -159.645670  22.150340                                    Kalalau Lookout
# ..          ...        ...                                                ...
# 365 -157.968056  21.321667  Fort Kamehameha Military Reservation (historical)
# 366 -157.982222  21.320556                           Fort Weaver (historical)
# 367 -157.953889  21.371389                         Battery Adair (historical)
# 368 -157.969167  21.367222                          Battery Boyd (historical)
# 369 -158.039722  21.484722                Wheeler Air Force Base (historical)
#
#                              info
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# ..                            ...
# 365        Pearl Harbor, Honolulu
# 366        Pearl Harbor, Honolulu
# 367        Pearl Harbor, Honolulu
# 368        Pearl Harbor, Honolulu
# 369  Schofield Barracks, Honolulu
#
# [370 rows x 4 columns]

# %% [markdown]
# ### Folium
#
# Now that we got the two datasets, we can see both have geo spatial data with longitude and latitude. Folium is an excellent resource that allows us visualize these geo data with interactive maps. Thus, for this problem, we create a folium chart that incorporates the airbnb listings with a heatmap, and the poi_factory data as clusters.

# %%
map1 = folium.Map(location=[37, -121], zoom_start=3)

stationArr = airbnb_data[['latitude', 'longitude', 'count']].values


#Commented out to save space. Make sure your computer can handle folium charts!
map1.add_children(plugins.HeatMap(stationArr, radius=15))

mc = MarkerCluster()

for index, row in usapoi_data.iterrows():
    mc.add_child(folium.Marker(location=[row['latitude'], row['longitude']]))
    
map1.add_child(mc)

#Illustrating clusters (count of individual places rows) with heatmap
map1
# Out:
# <ipython-input-6-f4fb81a528d2>:7: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
#   map1.add_children(plugins.HeatMap(stationArr, radius=15))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c8069f6d6585493dbfade845293d248d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20 ...

# %% [markdown]
# We see that most of the popular tourist sites have a LOT of listings inside them. This allows us to sort of understand what creates the "interest" for hosts and customers to choose these locations. If we zoom even closer, a lot of the attractions are located within the edges of the islands, most likely because of the beaches and the tropical view.
#
# Likewise, we can see a lot of the hosts are clumped into the edges through the map. When we view the specific areas, we can see that most of the hosts also like to choose near the edges, or at least outside mountains or trails.

# %% [markdown]
# Another great tool we utilized to visualize this data was through kepler. An example is shown in the code folders.
#
# https://kepler.gl/demo
